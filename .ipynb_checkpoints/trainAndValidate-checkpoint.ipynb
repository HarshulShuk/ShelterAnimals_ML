# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import numpy as np

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix

DATA_FILE_NAME = "ProcessedData.csv"
df = pd.read_csv(DATA_FILE_NAME)
df = df.sample(frac=1).reset_index(drop=True)

# %%
totalTrainingSet, totalTestSet = train_test_split(df,test_size=.2)
len(totalTrainingSet)
# Out:
# 17396

# %%
fold = KFold(n_splits = 5)


#classifier = MLPClassifier(hidden_layer_sizes=(32,16,10),max_iter=468)
#classifier.fit(train.iloc[:,1:],train.iloc[:,0])
#predictions = classifier.predict(validate.iloc[:,1:])
n100 = []
n1000 = []
values = dict()
estimators = [100,1000]
criteria = ['gini','entropy']
minSamplesLeaf = [5,15,50]

for i in range(0,5):
    split = next(fold.split(totalTrainingSet), None)
    train = totalTrainingSet.iloc[split[0]]
    validate = totalTrainingSet.iloc[split[1]]
    for est in estimators:
        for crit in criteria:
            for numSamp in minSamplesLeaf:
                classifier = RandomForestClassifier(n_estimators=est,criterion=crit,min_samples_leaf=numSamp)
                classifier.fit(train.iloc[:,1:],train.iloc[:,0])
                predictions = classifier.predict(validate.iloc[:,1:])
                score = accuracy_score(validate.iloc[:,0],predictions) 
                
                key = str(est) + "/" + str(crit) + "/" + str(numSamp)
                if key in values.keys():
                    values[key] = values[key] + score
                else:
                    values[key] = [float(score)]
            
    
values
# Out:
# {'100/gini/5': array([3.74712644]),
#  '100/gini/15': array([3.73994253]),
#  '100/gini/50': array([3.73994253]),
#  '100/entropy/5': array([3.74511494]),
#  '100/entropy/15': array([3.73994253]),
#  '100/entropy/50': array([3.73994253]),
#  '1000/gini/5': array([3.74482759]),
#  '1000/gini/15': array([3.73994253]),
#  '1000/gini/50': array([3.73994253]),
#  '1000/entropy/5': array([3.74252874]),
#  '1000/entropy/15': array([3.73994253]),
#  '1000/entropy/50': array([3.73994253])}

# %%
for key in values.keys():
    values[key] = values[key] / 5.0
max(values.items(), key=operator.itemgetter(1))[0]
# Out:
# {'100/gini/5': array([0.74942529]),
#  '100/gini/15': array([0.74798851]),
#  '100/gini/50': array([0.74798851]),
#  '100/entropy/5': array([0.74902299]),
#  '100/entropy/15': array([0.74798851]),
#  '100/entropy/50': array([0.74798851]),
#  '1000/gini/5': array([0.74896552]),
#  '1000/gini/15': array([0.74798851]),
#  '1000/gini/50': array([0.74798851]),
#  '1000/entropy/5': array([0.74850575]),
#  '1000/entropy/15': array([0.74798851]),
#  '1000/entropy/50': array([0.74798851])}

# %%
zipped = list(zip(totalTrainingSet.columns.values[1:],classifier.feature_importances_))
zipped
# Out:
# [('isPurebred', 0.0012323346483722264),
#  ('AnimalType_Cat', 0.04017559016262864),
#  ('AnimalType_Dog', 0.04435651138241933),
#  ('SexuponOutcome_Female', 0.009330496999257061),
#  ('SexuponOutcome_Male', 0.011347046349085135),
#  ('SexuponOutcome_Unknown', 0.05644022235318296),
#  ('AgeuponOutcome_Adolescent', 0.010925750263157187),
#  ('AgeuponOutcome_Adult', 0.01211187650055251),
#  ('AgeuponOutcome_Baby', 0.036303435047981454),
#  ('AgeuponOutcome_Senior', 0.030967584216856192),
#  ('AgeuponOutcome_Unknown', 0.0),
#  ('ReproductiveStatus_Intact', 0.2132086350539682),
#  ('ReproductiveStatus_Neutered', 0.27555248794752946),
#  ('ReproductiveStatus_Unknown', 0.06707273314210303),
#  ('Breed_Abyssinian Mix', 0.0),
#  ('Breed_Affenpinscher', 0.0),
#  ('Breed_Affenpinscher Mix', 0.0),
#  ('Breed_Afghan Hound Mix', 0.0),
#  ('Breed_Airedale Terrier', 0.0),
#  ('Breed_Airedale Terrier Mix', 0.0),
#  ('Breed_Akita', 0.0),
#  ('Breed_Akita Mix', 0.0),
#  ('Breed_Alaskan Husky', 0.0),
#  ('Breed_Alaskan Husky Mix', 0.0),
#  ('Breed_Alaskan Malamute', 0.0),
#  ('Breed_Alaskan Malamute Mix', 0.0),
#  ('Breed_American Bulldog', 0.0),
#  ('Breed_American Bulldog Mix', 0.0),
#  ('Breed_American Eskimo', 0.0),
#  ('Breed_American Eskimo Mix', 0.0),
#  ('Breed_American Foxhound', 0.0),
#  ('Breed_American Foxhound Mix', 0.0),
#  ('Breed_American Pit Bull Terrier', 0.0),
#  ('Breed_American Pit Bull Terrier Mix', 0.0),
#  ('Breed_American Shorthair Mix', 0.0),
#  ('Breed_American Staffordshire Terrier', 0.0),
#  ('Breed_American Staffordshire Terrier Mix', 0.0),
#  ('Breed_Anatol Shepherd', 0.0),
#  ('Breed_Anatol Shepherd Mix', 0.0),
#  ('Breed_Angora Mix', 0.0),
#  ('Breed_Australian Cattle Dog', 0.001458348365840654),
#  ('Breed_Australian Cattle Dog Mix', 0.00044065771762500126),
#  ('Breed_Australian Kelpie', 0.0),
#  ('Breed_Australian Kelpie Mix', 0.0),
#  ('Breed_Australian Shepherd', 0.0),
#  ('Breed_Australian Shepherd Mix', 3.4959260349090826e-05),
#  ('Breed_Australian Terrier Mix', 0.0),
#  ('Breed_Balinese Mix', 0.0),
#  ('Breed_Basenji', 0.0),
#  ('Breed_Basenji Mix', 0.0),
#  ('Breed_Basset Hound', 0.0),
#  ('Breed_Basset Hound Mix', 0.0),
#  ('Breed_Beagle', 0.001396412917417607),
#  ('Breed_Beagle Mix', 0.0),
#  ('Breed_Bearded Collie Mix', 0.0),
#  ('Breed_Beauceron', 0.0),
#  ('Breed_Beauceron Mix', 0.0),
#  ('Breed_Bedlington Terr Mix', 0.0),
#  ('Breed_Belgian Malinois', 0.0),
#  ('Breed_Belgian Malinois Mix', 0.0),
#  ('Breed_Belgian Sheepdog', 0.0),
#  ('Breed_Belgian Sheepdog Mix', 0.0),
#  ('Breed_Belgian Tervuren', 0.0),
#  ('Breed_Belgian Tervuren Mix', 0.0),
#  ('Breed_Bengal', 0.0),
#  ('Breed_Bengal Mix', 0.0),
#  ('Breed_Bernese Mountain Dog', 0.0),
#  ('Breed_Bernese Mountain Dog Mix', 0.0),
#  ('Breed_Bichon Frise', 0.0),
#  ('Breed_Bichon Frise Mix', 0.0),
#  ('Breed_Black', 0.0),
#  ('Breed_Black Mouth Cur', 0.0),
#  ('Breed_Black Mouth Cur Mix', 0.0),
#  ('Breed_Bloodhound', 0.0),
#  ('Breed_Bloodhound Mix', 0.0),
#  ('Breed_Blue Lacy', 0.0),
#  ('Breed_Blue Lacy Mix', 0.0),
#  ('Breed_Bluetick Hound', 0.0),
#  ('Breed_Bluetick Hound Mix', 0.0),
#  ('Breed_Boerboel', 0.0),
#  ('Breed_Boerboel Mix', 0.0),
#  ('Breed_Bombay Mix', 0.0),
#  ('Breed_Border Collie', 0.003541172861806615),
#  ('Breed_Border Collie Mix', 0.0007904905171531661),
#  ('Breed_Border Terrier', 0.0),
#  ('Breed_Border Terrier Mix', 0.0),
#  ('Breed_Borzoi', 0.0),
#  ('Breed_Boston Terrier', 0.0),
#  ('Breed_Boston Terrier Mix', 0.0),
#  ('Breed_Boxer', 0.002216005230434337),
#  ('Breed_Boxer Mix', 0.00033086691715279785),
#  ('Breed_Boykin Span', 0.0),
#  ('Breed_Boykin Span Mix', 0.0),
#  ('Breed_British Shorthair', 0.0),
#  ('Breed_British Shorthair Mix', 0.0),
#  ('Breed_Brittany', 0.0),
#  ('Breed_Brittany Mix', 0.0),
#  ('Breed_Bruss Griffon', 0.0),
#  ('Breed_Bruss Griffon Mix', 0.0),
#  ('Breed_Bull Terrier', 0.0),
#  ('Breed_Bull Terrier Miniature', 0.0),
#  ('Breed_Bull Terrier Miniature Mix', 0.0),
#  ('Breed_Bull Terrier Mix', 0.0),
#  ('Breed_Bulldog', 0.0),
#  ('Breed_Bulldog Mix', 0.0),
#  ('Breed_Bullmastiff', 0.0),
#  ('Breed_Bullmastiff Mix', 0.0),
#  ('Breed_Burmese', 0.0),
#  ('Breed_Cairn Terrier', 0.0),
#  ('Breed_Cairn Terrier Mix', 0.0),
#  ('Breed_Canaan Dog', 0.0),
#  ('Breed_Canaan Dog Mix', 0.0),
#  ('Breed_Cane Corso', 0.0),
#  ('Breed_Cane Corso Mix', 0.0),
#  ('Breed_Cardigan Welsh Corgi', 0.0),
#  ('Breed_Cardigan Welsh Corgi Mix', 0.0),
#  ('Breed_Carolina Dog', 0.0),
#  ('Breed_Carolina Dog Mix', 0.0),
#  ('Breed_Catahoula', 0.0),
#  ('Breed_Catahoula Mix', 3.603878676799138e-05),
#  ('Breed_Cavalier Span', 0.0),
#  ('Breed_Cavalier Span Mix', 0.0),
#  ('Breed_Chesa Bay Retr', 0.0),
#  ('Breed_Chesa Bay Retr Mix', 0.0),
#  ('Breed_Chihuahua Longhair', 0.0),
#  ('Breed_Chihuahua Longhair Mix', 0.0),
#  ('Breed_Chihuahua Shorthair', 0.002946368628505939),
#  ('Breed_Chihuahua Shorthair Mix', 0.001947164684811933),
#  ('Breed_Chinese Crested', 0.0),
#  ('Breed_Chinese Crested Mix', 0.0),
#  ('Breed_Chinese Sharpei', 0.0),
#  ('Breed_Chinese Sharpei Mix', 0.0),
#  ('Breed_Chow Chow', 0.0),
#  ('Breed_Chow Chow Mix', 0.0),
#  ('Breed_Cocker Spaniel', 0.0),
#  ('Breed_Cocker Spaniel Mix', 0.0),
#  ('Breed_Collie Rough', 0.0),
#  ('Breed_Collie Rough Mix', 0.0),
#  ('Breed_Collie Smooth', 0.0),
#  ('Breed_Collie Smooth Mix', 0.0),
#  ('Breed_Cornish Rex Mix', 0.0),
#  ('Breed_Cymric Mix', 0.0),
#  ('Breed_Dachshund', 0.001881646576296259),
#  ('Breed_Dachshund Longhair', 0.0),
#  ('Breed_Dachshund Longhair Mix', 0.0),
#  ('Breed_Dachshund Mix', 0.0003030494289470749),
#  ('Breed_Dachshund Wirehair', 0.0),
#  ('Breed_Dachshund Wirehair Mix', 0.0),
#  ('Breed_Dalmatian', 0.0),
#  ('Breed_Dalmatian Mix', 0.0),
#  ('Breed_Devon Rex', 0.0),
#  ('Breed_Devon Rex Mix', 0.0),
#  ('Breed_Doberman Pinsch', 0.0),
#  ('Breed_Doberman Pinsch Mix', 0.0),
#  ('Breed_Dogo Argentino', 0.0),
#  ('Breed_Dogo Argentino Mix', 0.0),
#  ('Breed_Dogue De Bordeaux', 0.0),
#  ('Breed_Dogue De Bordeaux Mix', 0.0),
#  ('Breed_Domestic Longhair', 0.0),
#  ('Breed_Domestic Longhair Mix', 0.0037477515617077312),
#  ('Breed_Domestic Medium Hair', 0.0),
#  ('Breed_Domestic Medium Hair Mix', 0.0009738493798400179),
#  ('Breed_Domestic Shorthair', 0.00029566156180339044),
#  ('Breed_Domestic Shorthair Mix', 0.03238346806292027),
#  ('Breed_Dutch Shepherd', 0.0),
#  ('Breed_Dutch Shepherd Mix', 0.0),
#  ('Breed_English Bulldog', 0.0),
#  ('Breed_English Bulldog Mix', 0.0),
#  ('Breed_English Cocker Spaniel', 0.0),
#  ('Breed_English Cocker Spaniel Mix', 0.0),
#  ('Breed_English Coonhound', 0.0),
#  ('Breed_English Coonhound Mix', 0.0),
#  ('Breed_English Foxhound', 0.0),
#  ('Breed_English Foxhound Mix', 0.0),
#  ('Breed_English Pointer', 0.0),
#  ('Breed_English Pointer Mix', 0.0),
#  ('Breed_English Setter', 0.0),
#  ('Breed_English Setter Mix', 0.0),
#  ('Breed_English Shepherd', 0.0),
#  ('Breed_English Shepherd Mix', 0.0),
#  ('Breed_English Springer Spaniel', 0.0),
#  ('Breed_English Springer Spaniel Mix', 0.0),
#  ('Breed_Entlebucher Mix', 0.0),
#  ('Breed_Exotic Shorthair Mix', 0.0),
#  ('Breed_Feist Mix', 0.0),
#  ('Breed_Field Spaniel Mix', 0.0),
#  ('Breed_Finnish Spitz', 0.0),
#  ('Breed_Finnish Spitz Mix', 0.0),
#  ('Breed_Flat Coat Retriever', 0.0),
#  ('Breed_Flat Coat Retriever Mix', 0.0),
#  ('Breed_French Bulldog', 0.0),
#  ('Breed_French Bulldog Mix', 0.0),
#  ('Breed_German Pinscher', 0.0),
#  ('Breed_German Pinscher Mix', 0.0),
#  ('Breed_German Shepherd', 0.0014151995551158999),
#  ('Breed_German Shepherd Mix', 0.0027850128404163154),
#  ('Breed_German Shorthair Pointer', 0.0),
#  ('Breed_German Shorthair Pointer Mix', 0.0),
#  ('Breed_German Wirehaired Pointer', 0.0),
#  ('Breed_German Wirehaired Pointer Mix', 0.0),
#  ('Breed_Glen Of Imaal', 0.0),
#  ('Breed_Glen Of Imaal Mix', 0.0),
#  ('Breed_Golden Retriever', 0.0),
#  ('Breed_Golden Retriever Mix', 0.0),
#  ('Breed_Great Dane', 0.0),
#  ('Breed_Great Dane Mix', 0.0),
#  ('Breed_Great Pyrenees', 0.0),
#  ('Breed_Great Pyrenees Mix', 0.0),
#  ('Breed_Greater Swiss Mountain Dog Mix', 0.0),
#  ('Breed_Greyhound', 0.0),
#  ('Breed_Greyhound Mix', 0.0),
#  ('Breed_Harrier', 0.0),
#  ('Breed_Harrier Mix', 0.0),
#  ('Breed_Havana Brown Mix', 0.0),
#  ('Breed_Havanese', 0.0),
#  ('Breed_Havanese Mix', 0.0),
#  ('Breed_Himalayan', 0.0),
#  ('Breed_Himalayan Mix', 0.0),
#  ('Breed_Hovawart Mix', 0.0),
#  ('Breed_Ibizan Hound', 0.0),
#  ('Breed_Ibizan Hound Mix', 0.0),
#  ('Breed_Irish Setter', 0.0),
#  ('Breed_Irish Terrier', 0.0),
#  ('Breed_Irish Terrier Mix', 0.0),
#  ('Breed_Irish Wolfhound', 0.0),
#  ('Breed_Irish Wolfhound Mix', 0.0),
#  ('Breed_Italian Greyhound', 0.0),
#  ('Breed_Italian Greyhound Mix', 0.0),
#  ('Breed_Jack Russell Terrier', 0.0),
#  ('Breed_Jack Russell Terrier Mix', 0.0),
#  ('Breed_Japanese Bobtail', 0.0),
#  ('Breed_Japanese Bobtail Mix', 0.0),
#  ('Breed_Japanese Chin', 0.0),
#  ('Breed_Japanese Chin Mix', 0.0),
#  ('Breed_Javanese Mix', 0.0),
#  ('Breed_Jindo Mix', 0.0),
#  ('Breed_Keeshond', 0.0),
#  ('Breed_Keeshond Mix', 0.0),
#  ('Breed_Kuvasz', 0.0),
#  ('Breed_Labrador Retriever', 0.0067395495715856565),
#  ('Breed_Labrador Retriever Mix', 0.0042610220807892465),
#  ('Breed_Landseer Mix', 0.0),
#  ('Breed_Leonberger', 0.0),
#  ('Breed_Leonberger Mix', 0.0),
#  ('Breed_Lhasa Apso', 0.0),
#  ('Breed_Lhasa Apso Mix', 0.0),
#  ('Breed_Lowchen Mix', 0.0),
#  ('Breed_Maine Coon', 0.0),
#  ('Breed_Maine Coon Mix', 0.0),
#  ('Breed_Maltese', 0.0),
#  ('Breed_Maltese Mix', 0.0),
#  ('Breed_Manchester Terrier', 0.0),
#  ('Breed_Manchester Terrier Mix', 0.0),
#  ('Breed_Manx', 0.0),
#  ('Breed_Manx Mix', 0.0),
#  ('Breed_Mastiff', 0.0),
#  ('Breed_Mastiff Mix', 0.0),
#  ('Breed_Mexican Hairless Mix', 0.0),
#  ('Breed_Miniature Pinscher', 0.0),
#  ('Breed_Miniature Pinscher Mix', 0.0),
#  ('Breed_Miniature Poodle', 0.0002746133589687465),
#  ('Breed_Miniature Poodle Mix', 0.0027305858589221233),
#  ('Breed_Miniature Schnauzer', 0.0),
#  ('Breed_Miniature Schnauzer Mix', 0.0),
#  ('Breed_Munchkin Longhair Mix', 0.0),
#  ('Breed_Neapolitan Mastiff', 0.0),
#  ('Breed_Neapolitan Mastiff Mix', 0.0),
#  ('Breed_Newfoundland', 0.0),
#  ('Breed_Newfoundland Mix', 0.0),
#  ('Breed_Norfolk Terrier', 0.0),
#  ('Breed_Norfolk Terrier Mix', 0.0),
#  ('Breed_Norwegian Elkhound Mix', 0.0),
#  ('Breed_Norwegian Forest Cat Mix', 0.0),
#  ('Breed_Norwich Terrier', 0.0),
#  ('Breed_Norwich Terrier Mix', 0.0),
#  ('Breed_Nova Scotia Duck Tolling Retriever', 0.0),
#  ('Breed_Nova Scotia Duck Tolling Retriever Mix', 0.0),
#  ('Breed_Ocicat Mix', 0.0),
#  ('Breed_Old English Bulldog Mix', 0.0),
#  ('Breed_Old English Sheepdog', 0.0),
#  ('Breed_Otterhound Mix', 0.0),
#  ('Breed_Papillon', 0.0),
#  ('Breed_Papillon Mix', 0.0),
#  ('Breed_Parson Russell Terrier', 0.0),
#  ('Breed_Parson Russell Terrier Mix', 0.0),
#  ('Breed_Patterdale Terr', 0.0),
#  ('Breed_Patterdale Terr Mix', 0.0),
#  ('Breed_Pbgv', 0.0),
#  ('Breed_Pbgv Mix', 0.0),
#  ('Breed_Pekingese', 0.0),
#  ('Breed_Pekingese Mix', 0.0),
#  ('Breed_Pembroke Welsh Corgi', 0.0),
#  ('Breed_Pembroke Welsh Corgi Mix', 0.0),
#  ('Breed_Persian', 0.0),
#  ('Breed_Persian Mix', 0.0),
#  ('Breed_Pharaoh Hound', 0.0),
#  ('Breed_Pharaoh Hound Mix', 0.0),
#  ('Breed_Picardy Sheepdog Mix', 0.0),
#  ('Breed_Pit Bull', 0.004012084497523829),
#  ('Breed_Pit Bull Mix', 0.016787696816561212),
#  ('Breed_Pixiebob Shorthair Mix', 0.0),
#  ('Breed_Plott Hound', 0.0),
#  ('Breed_Plott Hound Mix', 0.0),
#  ('Breed_Podengo Pequeno Mix', 0.0),
#  ('Breed_Pointer', 0.0),
#  ('Breed_Pointer Mix', 0.0),
#  ('Breed_Pomeranian', 0.0),
#  ('Breed_Pomeranian Mix', 0.0),
#  ('Breed_Port Water Dog Mix', 0.0),
#  ('Breed_Presa Canario', 0.0),
#  ('Breed_Presa Canario Mix', 0.0),
#  ('Breed_Pug', 0.0),
#  ('Breed_Pug Mix', 0.0),
#  ('Breed_Queensland Heeler', 0.0),
#  ('Breed_Queensland Heeler Mix', 0.0),
#  ('Breed_Ragdoll', 0.0),
#  ('Breed_Ragdoll Mix', 0.0),
#  ('Breed_Rat Terrier', 0.0),
#  ('Breed_Rat Terrier Mix', 8.886522800528117e-07),
#  ('Breed_Redbone Hound', 0.0),
#  ('Breed_Redbone Hound Mix', 0.0),
#  ('Breed_Rex', 0.0),
#  ('Breed_Rhod Ridgeback', 0.0),
#  ('Breed_Rhod Ridgeback Mix', 0.0),
#  ('Breed_Rottweiler', 0.0),
#  ('Breed_Rottweiler Mix', 0.0),
#  ('Breed_Russian Blue', 0.0),
#  ('Breed_Russian Blue Mix', 0.0),
#  ('Breed_Saluki', 0.0),
#  ('Breed_Saluki Mix', 0.0),
#  ('Breed_Samoyed Mix', 0.0),
#  ('Breed_Schipperke', 0.0),
#  ('Breed_Schipperke Mix', 0.0),
#  ('Breed_Schnauzer Giant', 0.0),
#  ('Breed_Schnauzer Giant Mix', 0.0),
#  ('Breed_Scottish Terrier', 0.0),
#  ('Breed_Scottish Terrier Mix', 0.0),
#  ('Breed_Sealyham Terr Mix', 0.0),
#  ('Breed_Shetland Sheepdog', 0.0),
#  ('Breed_Shetland Sheepdog Mix', 0.0),
#  ('Breed_Shiba Inu', 0.0),
#  ('Breed_Shiba Inu Mix', 0.0),
#  ('Breed_Shih Tzu', 0.0),
#  ('Breed_Shih Tzu Mix', 0.0),
#  ('Breed_Siamese', 0.0),
#  ('Breed_Siamese Mix', 0.001735806738918998),
#  ('Breed_Siberian Husky', 0.0),
#  ('Breed_Siberian Husky Mix', 0.0),
#  ('Breed_Silky Terrier', 0.0),
#  ('Breed_Silky Terrier Mix', 0.0),
#  ('Breed_Skye Terrier', 0.0),
#  ('Breed_Skye Terrier Mix', 0.0),
#  ('Breed_Smooth Fox Terrier', 0.0),
#  ('Breed_Smooth Fox Terrier Mix', 0.0),
#  ('Breed_Snowshoe', 0.0),
#  ('Breed_Snowshoe Mix', 0.0),
#  ('Breed_Soft Coated Wheaten Terrier', 0.0),
#  ('Breed_Soft Coated Wheaten Terrier Mix', 0.0),
#  ('Breed_Spanish Mastiff Mix', 0.0),
#  ('Breed_Spanish Water Dog', 0.0),
#  ('Breed_Sphynx', 0.0),
#  ('Breed_Spinone Italiano Mix', 0.0),
#  ('Breed_St. Bernard Rough Coat', 0.0),
#  ('Breed_St. Bernard Rough Coat Mix', 0.0),
#  ('Breed_St. Bernard Smooth Coat', 0.0),
#  ('Breed_St. Bernard Smooth Coat Mix', 0.0),
#  ('Breed_Staffordshire', 0.0),
#  ('Breed_Staffordshire Mix', 0.0),
#  ('Breed_Standard Poodle', 0.0),
#  ('Breed_Standard Poodle Mix', 0.0),
#  ('Breed_Standard Schnauzer', 0.0),
#  ('Breed_Standard Schnauzer Mix', 0.0),
#  ('Breed_Swedish Vallhund', 0.0),
#  ('Breed_Swedish Vallhund Mix', 0.0),
#  ('Breed_Swiss Hound', 0.0),
#  ('Breed_Tan Hound', 0.0),
#  ('Breed_Tan Hound Mix', 0.0),
#  ('Breed_Tibetan Spaniel', 0.0),
#  ('Breed_Tibetan Spaniel Mix', 0.0),
#  ('Breed_Tibetan Terrier', 0.0),
#  ('Breed_Tibetan Terrier Mix', 0.0),
#  ('Breed_Tonkinese Mix', 0.0),
#  ('Breed_Toy Fox Terrier', 0.0),
#  ('Breed_Toy Fox Terrier Mix', 0.0),
#  ('Breed_Toy Poodle', 0.0),
#  ('Breed_Toy Poodle Mix', 0.0),
#  ('Breed_Treeing Cur Mix', 0.0),
#  ('Breed_Treeing Tennesse Brindle', 0.0),
#  ('Breed_Treeing Walker Coonhound', 0.0),
#  ('Breed_Treeing Walker Coonhound Mix', 0.0),
#  ('Breed_Turkish Van Mix', 0.0),
#  ('Breed_Unknown', 0.0),
#  ('Breed_Unknown Mix', 0.0),
#  ('Breed_Vizsla', 0.0),
#  ('Breed_Vizsla Mix', 0.0),
#  ('Breed_Weimaraner', 0.0),
#  ('Breed_Weimaraner Mix', 0.0),
#  ('Breed_Welsh Springer Spaniel', 0.0),
#  ('Breed_Welsh Springer Spaniel Mix', 0.0),
#  ('Breed_Welsh Terrier', 0.0),
#  ('Breed_Welsh Terrier Mix', 0.0),
#  ('Breed_West Highland', 0.0),
#  ('Breed_West Highland Mix', 0.0),
#  ('Breed_Whippet', 0.0),
#  ('Breed_Whippet Mix', 0.0),
#  ('Breed_Wire Hair Fox Terrier', 0.0),
#  ('Breed_Wire Hair Fox Terrier Mix', 0.0),
#  ('Breed_Wirehaired Pointing Griffon Mix', 0.0),
#  ('Breed_Yorkshire', 0.0),
#  ('Breed_Yorkshire Terrier', 0.0),
#  ('Breed_Yorkshire Terrier Mix', 0.0),
#  ('Color_Agouti', 0.0),
#  ('Color_Apricot', 0.0),
#  ('Color_Black', 0.0025968065625149896),
#  ('Color_Black Brindle', 0.0),
#  ('Color_Black Smoke', 0.0),
#  ('Color_Black Tabby', 0.0),
#  ('Color_Black Tiger', 0.0),
#  ('Color_Blue', 0.0011952324887109598),
#  ('Color_Blue Cream', 0.0),
#  ('Color_Blue Merle', 0.002319575669422677),
#  ('Color_Blue Point', 0.0),
#  ('Color_Blue Smoke', 0.0),
#  ('Color_Blue Tabby', 0.0006702172538666376),
#  ('Color_Blue Tick', 0.0),
#  ('Color_Blue Tiger', 0.0),
#  ('Color_Brown', 0.006069593606367546),
#  ('Color_Brown Brindle', 0.003873649197147405),
#  ('Color_Brown Merle', 0.0),
#  ('Color_Brown Tabby', 0.010705887107832287),
#  ('Color_Brown Tiger', 0.0),
#  ('Color_Buff', 0.00023892103599658512),
#  ('Color_Calico', 0.0005679577830307818),
#  ('Color_Calico Point', 0.0),
#  ('Color_Chocolate', 0.0010082265953558509),
#  ('Color_Chocolate Point', 0.0),
#  ('Color_Cream', 0.0004319570832404793),
#  ('Color_Cream Tabby', 0.00030112410294354935),
#  ('Color_Fawn', 0.00015850213032519097),
#  ('Color_Flame Point', 0.0),
#  ('Color_Gold', 0.0),
#  ('Color_Gray', 0.0002376603050997302),
#  ('Color_Gray Tabby', 0.0),
#  ('Color_Lilac Point', 0.0),
#  ('Color_Liver', 0.0),
#  ('Color_Liver Tick', 0.0),
#  ('Color_Lynx Point', 0.000619051676489054),
#  ('Color_Orange', 0.0),
#  ('Color_Orange Tabby', 0.0020272189342848707),
#  ('Color_Orange Tiger', 0.0),
#  ('Color_Pink', 0.0),
#  ('Color_Red', 0.001628743059600952),
#  ('Color_Red Merle', 0.0),
#  ('Color_Red Tick', 0.0),
#  ('Color_Ruddy', 0.0),
#  ('Color_Sable', 0.0037217200541623365),
#  ('Color_Seal Point', 0.0010201970862300646),
#  ('Color_Silver', 0.0),
#  ('Color_Silver Lynx Point', 0.0),
#  ('Color_Silver Tabby', 0.0),
#  ('Color_Tan', 0.007279490606182491),
#  ('Color_Torbie', 0.00036853070616239396),
#  ('Color_Tortie', 0.0024694357320326314),
#  ('Color_Tortie Point', 0.0),
#  ('Color_Tricolor', 0.0009375708297682847),
#  ('Color_White', 0.0059832987831796225),
#  ('Color_Yellow', 7.835511249764837e-05),
#  ('Color_Yellow Brindle', 0.0)]

# %%
sorted(zipped, key=lambda x: x[1])[-9:]

# %%
classes = ['Adoption','Return_to_owner','Transfer','Euthanasia','Died']

normalize = True
cm =confusion_matrix(validate.iloc[:,0],predictions)

fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
# We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       # ... and label them with the respective list entries
       xticklabels=classes, yticklabels=classes,
       title= "Animal Outcomes",
       ylabel='True label',
       xlabel='Predicted label')
fmt = '.2f' if normalize else 'd'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

plt.show()
