# %%
import matplotlib.pyplot as plt
import pandas as pd

DATA_FILE_NAME = "PlottingData.csv"
df = pd.read_csv(DATA_FILE_NAME)
data_size=len(df)
df
# Out:
#        OutcomeType AnimalType SexuponOutcome AgeuponOutcome  \
# 0                1        Dog           Male     Adolescent
# 1                3        Cat         Female     Adolescent
# 2                0        Dog           Male     Adolescent
# 3                2        Cat           Male           Baby
# 4                2        Dog           Male     Adolescent
# 5                2        Dog         Female           Baby
# 6                2        Cat           Male           Baby
# 7                2        Cat        Unknown           Baby
# 8                0        Dog         Female           Baby
# 9                0        Dog         Female     Adolescent
# 10               2        Cat        Unknown     Adolescent
# 11               0        Dog         Female     Adolescent
# 12               0        Dog           Male          Adult
# 13               1        Dog           Male     Adolescent
# 14               1        Dog           Male     Adolescent
# 15               0        Cat           Male           Baby
# 16               2        Cat           Male           Baby
# 17               2        Dog         Female           Baby
# 18               2        Cat         Female     Adolescent
# 19               1        Dog           Male     Adolescent
# 20               2        Dog           Male           Baby
# 21               2        Cat         Female     Adolescent
# 22               0        Dog         Female     Adolescent
# 23               0        Dog           Male     Adolescent
# 24               1        Dog           Male           Baby
# 25               2        Cat         Female           Baby
# 26               0        Dog         Female           Baby
# 27               0        Dog         Female          Adult
# 28               0        Cat         Female           Baby
# 29               1        Cat           Male          Adult
# ...            ...        ...            ...            ...
# 26699            3        Dog           Male     Adolescent
# 26700            1        Dog           Male     Adolescent
# 26701            2        Dog         Female     Adolescent
# 26702            4        Cat         Female     Adolescent
# 26703            2        Cat           Male          Adult
# 26704            2        Cat         Female           Baby
# 26705            2        Cat         Female           Baby
# 26706            0        Cat         Female           Baby
# 26707            3        Cat        Unknown     Adolescent
# 26708            2        Dog           Male     Adolescent
# 26709            0        Dog         Female           Baby
# 26710            2        Dog         Female           Baby
# 26711            2        Dog         Female     Adolescent
# 26712            1        Dog           Male         Senior
# 26713            3        Cat         Female         Senior
# 26714            0        Cat         Female           Baby
# 26715            0        Dog         Female           Baby
# 26716            0        Dog           Male           Baby
# 26717            1        Dog         Female         Senior
# 26718            0        Dog           Male           Baby
# 26719            2        Cat        Unknown     Adolescent
# 26720            0        Cat         Female           Baby
# 26721            0        Cat         Female          Adult
# 26722            2        Cat           Male           Baby
# 26723            0        Dog           Male          Adult
# 26724            2        Cat           Male           Baby
# 26725            2        Cat         Female           Baby
# 26726            0        Dog           Male          Adult
# 26727            2        Cat           Male           Baby
# 26728            2        Cat           Male     Adolescent
#
#                                        Breed                Color  isPurebred  \
# 0                      Shetland Sheepdog Mix          Brown/White           0
# 1                     Domestic Shorthair Mix          Cream Tabby           0
# 2                               Pit Bull Mix           Blue/White           0
# 3                     Domestic Shorthair Mix           Blue Cream           0
# 4                Lhasa Apso/Miniature Poodle                  Tan           0
# 5          Cairn Terrier/Chihuahua Shorthair            Black/Tan           0
# 6                     Domestic Shorthair Mix           Blue Tabby           0
# 7                     Domestic Shorthair Mix          Brown Tabby           0
# 8              American Pit Bull Terrier Mix            Red/White           0
# 9                              Cairn Terrier                White           1
# 10                    Domestic Shorthair Mix                Black           0
# 11                   Miniature Schnauzer Mix               Silver           0
# 12                              Pit Bull Mix                Brown           0
# 26706           Neutered
# 26707            Unknown
# 26708           Neutered
# 26709           Neutered
# 26710             Intact
# 26711             Intact
# 26712           Neutered
# 26713             Intact
# 26714           Neutered
# 26715           Neutered
# 26716           Neutered
# 26717           Neutered
# 26718           Neutered
# 26719            Unknown
# 26720           Neutered
# 26721           Neutered
# 26722             Intact
# 26723           Neutered
# 26724             Intact
# 26725           Neutered
# 26726           Neutered
# 26727             Intact
# 26728             Intact
#
# [26729 rows x 8 columns]

# %%
outcome_types=df.groupby("OutcomeType")
for outcome in outcome_types.groups.keys():
    size=len(outcome_types.groups[outcome])
    print(outcome,size,round(size/data_size,2))
labels = ['Adopted','Returned to Owner','Transfered','Euthanized','Died']
outcomePlot = outcome_types['OutcomeType'].count().plot.pie(labels = labels,autopct = '%1.1f%%',title = "Distribution of OutcomeTypes")
outcomePlot.set_ylabel('')
plt.savefig('Animal_Outcome_Counts.png',bbox_inches = "tight")
# Out:
# 0 10769 0.4
# 1 4786 0.18
# 2 9422 0.35
# 3 1555 0.06
# 4 197 0.01

# %%
animalTypePlot = df.groupby("AnimalType")["AnimalType"].count().plot.bar(title = "Animal Types")
plt.savefig('Animal_Type_Counts.png',bbox_inches = "tight")

# %%
#color_types = df.groupby(['Color 1','Color 2'])['OutcomeType'].count().rename(columns={"OutcomeType":"Count"})
plt.rcParams["figure.figsize"] = (20,3)
plt.subplot(1,2,1)
color_types = df.groupby(['Color']).size()#.reset_index(name='counts')
data = pd.Series({'1': color_types[color_types == 1].count(),
        '2-10': color_types[(color_types >= 2) & (color_types <= 10)].count(),
        '11-100': color_types[(color_types >= 11) & (color_types <= 100)].count(),
        '101-1000': color_types[(color_types >= 101) & (color_types <= 1000)].count(),
        '1001-3005': color_types[(color_types > 1000)].count()
       })
colorPlot = data.plot.bar(title='Color Frequency')
colorPlot.set_ylabel('Number of Colors')
colorPlot.set_xlabel('Frequency appeared')

plt.subplot(1,2,2)
breed_types = df.groupby(['Breed']).size()#.reset_index(name='counts')
data = pd.Series({'1': breed_types[breed_types == 1].count(),
        '2-10': breed_types[(breed_types >= 2) & (breed_types <= 10)].count(),
        '11-100': breed_types[(breed_types >= 11) & (breed_types <= 100)].count(),
        '101-1000': breed_types[(breed_types >= 101) & (breed_types <= 1000)].count(),
        '1001-3005': breed_types[(breed_types > 1000)].count()
       })
breedPlot = data.plot.bar(title='Breed Frequency')
breedPlot.set_ylabel('Number of Colors')
breedPlot.set_xlabel('Frequency appeared')
plt.subplots_adjust(wspace=.3)
plt.savefig('Color_Breed.png',bbox_inches = "tight")

# %%
color1 = ['C0','C1','C2']
color2 = ['C3','C4','C9']
plt.subplot(1,2,1)
sex_types = df.groupby('SexuponOutcome')['SexuponOutcome'].count().plot.pie(colors = color1,autopct = '%1.1f%%', title = "Gender Distribution")
sex_types.set_ylabel('')
plt.subplot(1,2,2)
reproTypes = df.groupby('ReproductiveStatus')['ReproductiveStatus'].count().plot.pie(colors = color2,autopct = '%1.1f%%', title = "Reproductive Capability Distribution")
reproTypes.set_ylabel('')

#labels = labels,autopct = '%1.1f%%',title = "Distribution of OutcomeTypes"

plt.savefig('Sex_ReproductiveStatus.png',bbox_inches = "tight")
